# %% [markdown]
# # Prepare complete dataset
# When comparing two datasets fetched from SpaceX API and Falcon 9 Wikipedia page, I can see that there are valuable data in both csv files. But these files cannot be merged together.
# So, I have to collect data from both csv file and prepare a complete dataset.
#
# In this Notebook I combine data from both csv files and prepare a complete and final dataset.

# %%
import pandas as pd
import numpy as np
import csv, sqlite3, sqlalchemy

# %%
df_api = pd.read_csv("spacex_falcon9.csv")
df_api.head(10)
# Out:
#    FlightNumber        Date BoosterVersion  PayloadMass Orbit    LaunchSite  \
# 0             1  2010-06-04       Falcon 9   8191.07911   LEO  CCSFS SLC 40
# 1             2  2012-05-22       Falcon 9    525.00000   LEO  CCSFS SLC 40
# 2             3  2013-03-01       Falcon 9    677.00000   ISS  CCSFS SLC 40
# 3             4  2013-09-29       Falcon 9    500.00000    PO   VAFB SLC 4E
# 4             5  2013-12-03       Falcon 9   3170.00000   GTO  CCSFS SLC 40
# 5             6  2014-01-06       Falcon 9   3325.00000   GTO  CCSFS SLC 40
# 6             7  2014-04-18       Falcon 9   2296.00000   ISS  CCSFS SLC 40
# 7             8  2014-07-14       Falcon 9   1316.00000   LEO  CCSFS SLC 40
# 8             9  2014-08-05       Falcon 9   4535.00000   GTO  CCSFS SLC 40
# 9            10  2014-09-07       Falcon 9   4428.00000   GTO  CCSFS SLC 40
#
#        Outcome  Flights  GridFins  Reused   Legs LandingPad  Block  \
# 0    None None        1     False   False  False        NaN    1.0
# 1    None None        1     False   False  False        NaN    1.0
# 2    None None        1     False   False  False        NaN    1.0
# 3  False Ocean        1     False   False  False        NaN    1.0
# 4    None None        1     False   False  False        NaN    1.0
# 5    None None        1     False   False  False        NaN    1.0
# 6   True Ocean        1     False   False   True        NaN    1.0
# 7   True Ocean        1     False   False   True        NaN    1.0
# 8    None None        1     False   False  False        NaN    1.0
# 9    None None        1     False   False  False        NaN    1.0
#
#    ReusedCount Serial   Longitude   Latitude
# 0            0  B0003  -80.577366  28.561857
# 1            0  B0005  -80.577366  28.561857
# 2            0  B0007  -80.577366  28.561857
# 3            0  B1003 -120.610829  34.632093
# 4            0  B1004  -80.577366  28.561857
# 5            0  B1005  -80.577366  28.561857
# 6            0  B1006  -80.577366  28.561857
# 7            0  B1007  -80.577366  28.561857
# 8            0  B1008  -80.577366  28.561857
# 9            0  B1011  -80.577366  28.561857

# %%
df_wiki = pd.read_csv("spacex_falcon9_wiki.csv")
df_wiki.head(10)
# Out:
#    Flight No. Launch site                               Payload Payload mass  \
# 0           1       CCSFS  Dragon Spacecraft Qualification Unit            N
# 1           2       CCSFS             SpaceX COTS Demo Flight 1            U
# 2           3       CCSFS             SpaceX COTS Demo Flight 2       525 kg
# 3           4       CCSFS                          SpaceX CRS-1     4,700 kg
# 4           5       CCSFS                          SpaceX CRS-2     4,877 kg
# 5           6        VSFB                              CASSIOPE       500 kg
# 6           7       CCSFS                                 SES-8     3,170 kg
# 7           8       CCSFS                             Thaicom 6     3,325 kg
# 8           9       CCSFS                          SpaceX CRS-3     2,296 kg
# 9          10       CCSFS                           Orbcomm-OG2     1,316 kg
#
#          Orbit Customer Launch outcome Version Booster Booster landing  \
# 0          LEO   SpaceX        Success         F9 v1.0         Failure
# 1          LEO     NASA        Success         F9 v1.0         Failure
# 2          LEO     NASA        Success         F9 v1.0      No attempt
# 3          LEO     NASA        Success         F9 v1.0      No attempt
# 4          LEO     NASA        Success         F9 v1.0      No attempt
# 5  Polar orbit      MDA        Success         F9 v1.1    Uncontrolled
# 6          GTO      SES        Success         F9 v1.1      No attempt
# 7          GTO  Thaicom        Success         F9 v1.1      No attempt
# 8          LEO     NASA        Success         F9 v1.1      Controlled
# 9          LEO  Orbcomm        Success         F9 v1.1      Controlled
#
#          Date      Time
# 0  2010-06-04  18:45:00
# 1  2010-12-08  15:43:00
# 2  2012-05-22  07:44:00
# 3  2012-10-08  00:35:00
# 4  2013-03-01  15:10:00
# 5  2013-09-29  16:00:00
# 6  2013-12-03  22:41:00
# 7  2014-01-06  22:06:00
# 8  2014-04-18  19:25:00
# 9  2014-07-14  15:15:00

# %%
df_api.shape
# Out:
# (168, 17)

# %%
df_wiki.shape
# Out:
# (243, 11)

# %% [markdown]
# <div class="alert alert-info">
#     <h4>Observations:</h4>
#     <ol>
#         <li>There are more observations from Wikipedia page than SpaceX API</li>
#     </ol>
# </div>

# %% [markdown]
# I will take Wikipedia dataset as the base dataset and fill it up with the information taken from SpaceX API dataset.

# %% [markdown]
# Launch sites from API

# %%
df_api['LaunchSite'].value_counts()
# Out:
# CCSFS SLC 40    93
# KSC LC 39A      49
# VAFB SLC 4E     26
# Name: LaunchSite, dtype: int64

# %% [markdown]
# #### Replace Launch Sites with proper names

# %%
launch_site_dict = {
    'CCSFS': 'CCSFS SLC 40',
    'KSC': 'KSC LC 39A',
    'VSFB': 'VAFB SLC 4E',
    'VAFB': 'VAFB SLC 4E'
}

df_wiki['Launch site'].replace(launch_site_dict, inplace=True)

# %%
df_wiki['Launch site'].unique()
# Out:
# array(['CCSFS SLC 40', 'VAFB SLC 4E', 'KSC LC 39A'], dtype=object)

# %% [markdown]
# #### Correct the *Payload mass* values
# - Remove the unit kg and the comma
# - Replace char values with numbers
# - Set float type

# %%
corrected_payload_mass_list = []

for payload_mass in df_wiki['Payload mass']:
    new_pm = payload_mass.strip(' kg').replace(',', '')
    if not new_pm.isdigit():
        new_pm = 0
    corrected_payload_mass_list.append(new_pm)
    
df_wiki['Payload mass'] = corrected_payload_mass_list

# %%
df_wiki.head()
# Out:
#    Flight No.   Launch site                               Payload  \
# 0           1  CCSFS SLC 40  Dragon Spacecraft Qualification Unit
# 1           2  CCSFS SLC 40             SpaceX COTS Demo Flight 1
# 2           3  CCSFS SLC 40             SpaceX COTS Demo Flight 2
# 3           4  CCSFS SLC 40                          SpaceX CRS-1
# 4           5  CCSFS SLC 40                          SpaceX CRS-2
#
#   Payload mass Orbit Customer Launch outcome Version Booster Booster landing  \
# 0            0   LEO   SpaceX        Success         F9 v1.0         Failure
# 1            0   LEO     NASA        Success         F9 v1.0         Failure
# 2          525   LEO     NASA        Success         F9 v1.0      No attempt
# 3         4700   LEO     NASA        Success         F9 v1.0      No attempt
# 4         4877   LEO     NASA        Success         F9 v1.0      No attempt
#
#          Date      Time
# 0  2010-06-04  18:45:00
# 1  2010-12-08  15:43:00
# 2  2012-05-22  07:44:00
# 3  2012-10-08  00:35:00
# 4  2013-03-01  15:10:00

# %%
df_wiki['Payload mass'] = df_wiki['Payload mass'].astype('float')

# %%
df_wiki.head()
# Out:
#    Flight No.   Launch site                               Payload  \
# 0           1  CCSFS SLC 40  Dragon Spacecraft Qualification Unit
# 1           2  CCSFS SLC 40             SpaceX COTS Demo Flight 1
# 2           3  CCSFS SLC 40             SpaceX COTS Demo Flight 2
# 3           4  CCSFS SLC 40                          SpaceX CRS-1
# 4           5  CCSFS SLC 40                          SpaceX CRS-2
#
#    Payload mass Orbit Customer Launch outcome Version Booster Booster landing  \
# 0           0.0   LEO   SpaceX        Success         F9 v1.0         Failure
# 1           0.0   LEO     NASA        Success         F9 v1.0         Failure
# 2         525.0   LEO     NASA        Success         F9 v1.0      No attempt
# 3        4700.0   LEO     NASA        Success         F9 v1.0      No attempt
# 4        4877.0   LEO     NASA        Success         F9 v1.0      No attempt
#
#          Date      Time
# 0  2010-06-04  18:45:00
# 1  2010-12-08  15:43:00
# 2  2012-05-22  07:44:00
# 3  2012-10-08  00:35:00
# 4  2013-03-01  15:10:00

# %% [markdown]
# #### Location data of Launch sites is also important
# Let's take them from SpaceX API dataset and append them in Wikipedia dataset

# %%
latitude = []
longitude = []

for launch_site in list(df_wiki['Launch site']):
    lon = df_api[df_api['LaunchSite'] == launch_site]['Longitude'].unique()[0]
    lat = df_api[df_api['LaunchSite'] == launch_site]['Latitude'].unique()[0]
    
    latitude.append(lat)
    longitude.append(lon)
    
df_wiki['Longitude'] = longitude
df_wiki['Latitude'] = latitude

# %%
df_wiki
# Out:
#      Flight No.   Launch site                               Payload  \
# 0             1  CCSFS SLC 40  Dragon Spacecraft Qualification Unit
# 1             2  CCSFS SLC 40             SpaceX COTS Demo Flight 1
# 2             3  CCSFS SLC 40             SpaceX COTS Demo Flight 2
# 3             4  CCSFS SLC 40                          SpaceX CRS-1
# 4             5  CCSFS SLC 40                          SpaceX CRS-2
# ..          ...           ...                                   ...
# 238         239  CCSFS SLC 40                   Starlink Group 5-15
# 239         240   VAFB SLC 4E                   Starlink Group 6-15
# 240         241  CCSFS SLC 40                    Starlink Group 6-6
# 241         242  CCSFS SLC 40                    Starlink Group 6-7
# 242         243  CCSFS SLC 40                             Galaxy 37
#
#      Payload mass Orbit  Customer Launch outcome Version Booster  \
# 0             0.0   LEO    SpaceX        Success         F9 v1.0
# 1             0.0   LEO      NASA        Success         F9 v1.0
# 2           525.0   LEO      NASA        Success         F9 v1.0
# 3          4700.0   LEO      NASA        Success         F9 v1.0
# 4          4877.0   LEO      NASA        Success         F9 v1.0
# ..            ...   ...       ...            ...             ...
# 238           0.0   LEO    SpaceX        Success           F9 B5
# 239           0.0   LEO    SpaceX        Success           F9 B5
# 240           0.0   LEO    SpaceX        Success           F9 B5
# 241           0.0   LEO    SpaceX        Success           F9 B5
# 242           0.0   GTO  Intelsat        Success           F9 B5
#
#     Booster landing        Date      Time   Longitude   Latitude
# 0           Failure  2010-06-04  18:45:00  -80.577366  28.561857
# 1           Failure  2010-12-08  15:43:00  -80.577366  28.561857
# 2        No attempt  2012-05-22  07:44:00  -80.577366  28.561857
# 3        No attempt  2012-10-08  00:35:00  -80.577366  28.561857
# 4        No attempt  2013-03-01  15:10:00  -80.577366  28.561857
# ..              ...         ...       ...         ...        ...
# 238         Success  2023-07-16  03:50:00  -80.577366  28.561857
# 239         Success  2023-07-20  04:09:00 -120.610829  34.632093
# 240         Success  2023-07-24  00:50:00  -80.577366  28.561857
# 241         Success  2023-07-28  04:01:00  -80.577366  28.561857
# 242         Success  2023-08-03  05:00:00  -80.577366  28.561857
#
# [243 rows x 13 columns]

# %%
df_wiki.dtypes
# Out:
# Flight No.           int64
# Launch site         object
# Payload             object
# Payload mass       float64
# Orbit               object
# Customer            object
# Launch outcome      object
# Version Booster     object
# Booster landing     object
# Date                object
# Time                object
# Longitude          float64
# Latitude           float64
# dtype: object

# %%
df_wiki['Launch outcome'].value_counts()
# Out:
# Success    242
# Failure      1
# Name: Launch outcome, dtype: int64

# %%
df_wiki['Booster landing'].value_counts()
# Out:
# Success         200
# No attempt       23
# Failure          11
# Controlled        6
# Uncontrolled      2
# Precluded         1
# Name: Booster landing, dtype: int64

# %% [markdown]
# #### Update column names

# %%
col_names = list(df_wiki.columns)

for i, col_name in enumerate(col_names):
    col_names[i] = col_name.title().replace(' ', '_').strip('.')
    
col_names
# Out:
# ['Flight_No',
#  'Launch_Site',
#  'Payload',
#  'Payload_Mass',
#  'Orbit',
#  'Customer',
#  'Launch_Outcome',
#  'Version_Booster',
#  'Booster_Landing',
#  'Date',
#  'Time',
#  'Longitude',
#  'Latitude']

# %%
df_wiki.columns = col_names

# %%
df_wiki.head()
# Out:
#    Flight_No   Launch_Site                               Payload  \
# 0          1  CCSFS SLC 40  Dragon Spacecraft Qualification Unit
# 1          2  CCSFS SLC 40             SpaceX COTS Demo Flight 1
# 2          3  CCSFS SLC 40             SpaceX COTS Demo Flight 2
# 3          4  CCSFS SLC 40                          SpaceX CRS-1
# 4          5  CCSFS SLC 40                          SpaceX CRS-2
#
#    Payload_Mass Orbit Customer Launch_Outcome Version_Booster Booster_Landing  \
# 0           0.0   LEO   SpaceX        Success         F9 v1.0         Failure
# 1           0.0   LEO     NASA        Success         F9 v1.0         Failure
# 2         525.0   LEO     NASA        Success         F9 v1.0      No attempt
# 3        4700.0   LEO     NASA        Success         F9 v1.0      No attempt
# 4        4877.0   LEO     NASA        Success         F9 v1.0      No attempt
#
#          Date      Time  Longitude   Latitude
# 0  2010-06-04  18:45:00 -80.577366  28.561857
# 1  2010-12-08  15:43:00 -80.577366  28.561857
# 2  2012-05-22  07:44:00 -80.577366  28.561857
# 3  2012-10-08  00:35:00 -80.577366  28.561857
# 4  2013-03-01  15:10:00 -80.577366  28.561857

# %% [markdown]
# #### Dealing with missing values

# %%
df_wiki.isna().sum()
# Out:
# Flight_No          0
# Launch_Site        0
# Payload            7
# Payload_Mass       0
# Orbit              2
# Customer           1
# Launch_Outcome     0
# Version_Booster    0
# Booster_Landing    0
# Date               0
# Time               0
# Longitude          0
# Latitude           0
# dtype: int64

# %%
df_wiki[df_wiki['Orbit'].isnull()]
# Out:
#      Flight_No   Launch_Site Payload  Payload_Mass Orbit Customer  \
# 14          15  CCSFS SLC 40  DSCOVR         570.0   NaN     USAF
# 235        236  CCSFS SLC 40  Euclid           0.0   NaN      ESA
#
#     Launch_Outcome Version_Booster Booster_Landing        Date      Time  \
# 14         Success         F9 v1.1      Controlled  2015-02-11  23:03:00
# 235        Success           F9 B5         Success  2023-07-01  15:12:00
#
#      Longitude   Latitude
# 14  -80.577366  28.561857
# 235 -80.577366  28.561857

# %% [markdown]
# ##### For this analysis the observation for missing Orbit value will be removed.

# %%
df_wiki.dropna(subset=['Orbit'], axis=0, inplace=True)

# %%
df_wiki.isna().sum()
# Out:
# Flight_No          0
# Launch_Site        0
# Payload            7
# Payload_Mass       0
# Orbit              0
# Customer           1
# Launch_Outcome     0
# Version_Booster    0
# Booster_Landing    0
# Date               0
# Time               0
# Longitude          0
# Latitude           0
# dtype: int64

# %% [markdown]
# ### Now dataset is ready to store in SQL database
# Let's create final *csv* file and also store data in SQlite database for future use.

# %%
df_wiki.to_csv('falcon9_final.csv', index=False)

# %%
df_wiki['Booster_Landing'].unique()
# Out:
# array(['Failure', 'No attempt', 'Uncontrolled', 'Controlled', 'Precluded',
#        'Success'], dtype=object)

# %% [markdown]
# #### SQlite database

# %%
con = sqlite3.connect("falcon9.db")
cur = con.cursor()

# %%
# save data in a SQlite databse table
df_wiki.to_sql("falcon9_tbl", con, if_exists='replace', index=False, method="multi")
# Out:
# 241

# %% [markdown]
# Now data is in SQlite database.
#
# - Please refer [SpaceX.ipynb](SpaceX.ipynb) Notebook file for the rest of the project.
#
# #### Data preparation
# - Please refer [Data_collection_spacex_api.ipynb](Data_collection_spacex_api.ipynb) for data collection SpaceX API.
# - Please refer [Data_collection_Webscraping.ipynb](Data_collection_Webscraping.ipynb) for webscraping data from Falcon 9 Wikipedia page.
# - Please refer [Complete_dataset.ipynb](Complete_dataset.ipynb) to see the implementatin of the final dataset.
